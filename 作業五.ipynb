# %% [markdown]
# <a href="https://colab.research.google.com/github/ziyu0223/python_learning/blob/main/%E4%BD%9C%E6%A5%AD%E4%BA%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_quadratic_equation(a, b, c):
    x = np.linspace(1,100)  # 在指定範圍內生成一組 x 值
    y = a * x**2 + b * x + c  # 計算對應的 y 值

    # 繪製圖形
    plt.plot(x, y)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Quadratic Equation')
    plt.grid(True)
    plt.show()

# 設定二元一次方程式的係數
a = -2
b = 4
c = 5

# 繪製二元一次方程式的圖形
plot_quadratic_equation(a, b, c)

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_quadratic_equation(a, b, c):
    x = np.linspace(1,100)  # 在指定範圍內生成一組 x 值
    y = a * x**2 + b * x + c  # 計算對應的 y 值

    # 繪製圖形
    plt.plot(x, y)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Quadratic Equation')
    plt.grid(True)
    plt.show()

# 設定二元一次方程式的係數
a = 3
b = 2
c = -6

# 繪製二元一次方程式的圖形
plot_quadratic_equation(a, b, c)
